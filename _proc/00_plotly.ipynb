# %% [raw]
# ---
# description: plotly json conversion to widget json for quatro
# output-file: plotly.html
# title: plotly
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(PlotlyProc)
# Out:
# ---
#
# ### PlotlyProc
#
# >      PlotlyProc (nb)
#
# A processor that will do the conversion for outputs
